# %% [markdown]
# # 4.2 Exercise
#
# # Alexander Hillberry
#
# # DSC 320-T301

# %% [markdown]
# ## Calculating Limits Numerically

# %% [markdown]
# ### a)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function f(x)
def f(x):
    return 2*x**3 - 4*x + 1

# Numerical calculation of the limit of f(x) as x approaches 3
x_values_a = np.linspace(2.5, 3.5, 100)
y_values_a = f(x_values_a)

# Plotting the function
plt.plot(x_values_a, y_values_a, label='2x^3 - 4x + 1')
plt.axvline(x=3, color='orange', label='x = 3 (limit)')
plt.title('Function f(x) and Limit Calculation')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %% [markdown]
# ### b)

# %%
# Function g(x)
def g(x):
    return np.exp(x - 1) / x

# Numerical calculation of the limit of g(x) as x approaches 0
x_values_b = np.linspace(-0.5, 0.5, 100)
y_values_b = g(x_values_b)

# Handling the division by zero for x = 0
y_values_b[np.isinf(y_values_b)] = np.nan

# Plotting the function
plt.plot(x_values_b, y_values_b, label='e^(x-1) / x')
plt.axvline(x=0, color='r', linestyle='--', label='x = 0 (limit)')
plt.title('Function g(x) and Limit Calculation')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.show()

# %% [markdown]
# ### c)

# %% [markdown]
# #### Could the limits in parts (a) and (b) be calculated by plugging in the value where the limit is takeninto the function? Explain. What does this mean in terms of continuity?
#
# ##### For part (a), the limit cannot be accurately calculated by substituting the value where the limit is taken into the function. This is because continutity requires that the limit be equal to the function at that point. For part (b), yes. The limit of the function as it approaches 0 could be calculated that way as it achieves continuity at 0.

# %% [markdown]
# ## Average Rate of Change

# %%
# Average Rate of Change
def average_rate_of_change(f, a, b):
    return (f(b) - f(a)) / (b - a)

# Example
f_example = lambda x: 3*x**2
a_example = 1
b_example = 2
average_rate_of_change(f_example, a_example, b_example)
# Out:
# 9.0

# %% [markdown]
# ## Average Rate of Change to Instantaneous Rate of Change

# %% [markdown]
# ### a)

# %%
# Part 1: Define the function f(t)
def f(t):
    return 4.9 * t**2

# Part 2: Calculate the average speed between 5 and 6 seconds
avg_speed_a = average_rate_of_change_numpy(f, 5, 6)
avg_speed_a
# Out:
# 53.89999999999999

# %% [markdown]
# ### b)

# %%
# Part 3: Calculate the average speed between 5 and 5.5 seconds
avg_speed_b = average_rate_of_change_numpy(f, 5, 5.5)
avg_speed_b
# Out:
# 51.45000000000002

# %% [markdown]
# ### c)

# %%
# Part 4: Calculate the average speed between 5 and 5.1 seconds
avg_speed_c = average_rate_of_change_numpy(f, 5, 5.1)
avg_speed_c
# Out:
# 49.490000000000016

# %% [markdown]
# ### d)

# %%
# Instantaneous speed at t = 5 seconds
t_values_d = np.array([4.9, 4.95, 4.99, 5, 5.01, 5.05])
instantaneous_speed_d = average_rate_of_change_numpy(f, t_values_d - 0.01, t_values_d + 0.01)

instantaneous_speed_d
# Out:
# array([48.02 , 48.51 , 48.902, 49.   , 49.098, 49.49 ])

# %% [markdown]
# ### e)

# %%
# Derivative of f(t)
def f_prime(t):
    return 2 * 4.9 * t

# %% [markdown]
# ### f)

# %%
# Evaluate derivative at t = 5
deriv_5 = f_prime(5)
deriv_5
# Out:
# 49.0

# %% [markdown]
# ## Calculating and Interpreting Partial Derivatives

# %% [markdown]
# ### a)

# %%
# Predicted selling price for a 5-year old car with a condition rating 8
C = 8
Y = 5
predicted_price = 16000 + 2400*C - 1800*Y
predicted_price
# Out:
# 26200

# %% [markdown]
# ### b)

# %%
# Partial derivative with respect to C
pderiv_C = 2400
pderiv_C
# Out:
# 2400

# %% [markdown]
# ### c)

# %%
# Partial derivative with respect to Y
pderiv_Y = -1800
pderiv_Y
# Out:
# -1800
